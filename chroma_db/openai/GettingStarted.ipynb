# %% [markdown]
# ### In this quickstart we'll see how to:
# <li>Get setup with langchain , Langchain and Langserver</li>
# <li>Use the most basic and common componenets of langchain: prompt templates , models and output a prsers.</li>
# <li>Build a simple application with langchain</li>
# <li>Trace your application with LangSmith</li>
# <li>Serve your application with Langserve</li>

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ['Gemini_API_Key'] = os.getenv('Gemini_API_Key')
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ["LANGCHAIN_PROJEC"] = os.getenv("LANGCHAIN_PROJEC")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

response = llm.invoke("What is Generative AI?")

print(response.content)
# Out:
# **Generative AI** is a type of artificial intelligence that can **create new, original content** across various modalities (text, images, audio, video, code, etc.) by learning patterns and structures from vast amounts of existing data.
#
# Unlike traditional AI that might classify, predict, or analyze existing data, generative AI's primary function is to **produce something novel** that resembles the data it was trained on, but isn't an exact copy.
#
# Here's a breakdown of what that means:
#
# 1.  **"Generative" vs. "Discriminative" AI:**
#     *   **Discriminative AI** (like a spam filter or image classifier) learns to distinguish between different types of data. It answers questions like "Is this email spam?" or "Is this picture a cat or a dog?"
# ...

# %%
## Chatt prompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system","You are an expert AI Enginner. Provide me answer based on the questions"),
    ("user","{input}")
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Enginner. Provide me answer based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm
response = chain.invoke({"input":"Can you tell me about Langsmith?"})
response.content
# Out:
# "LangSmith is a **developer platform built by the creators of LangChain** specifically designed to help engineers and teams build, debug, test, evaluate, and monitor LLM (Large Language Model) applications.\n\nThink of it as the **MLOps platform for your LLM applications**, providing the observability and tooling necessary to move from prototype to production with confidence.\n\nHere's a breakdown of what LangSmith is and why it's crucial for modern LLM development:\n\n## The Problem LangSmith Solves\n\nDeveloping reliable LLM applications is challenging for several reasons:\n\n1.  **Non-Determinism:** LLMs are inherently probabilistic. The same input might yield slightly different outputs, making debugging difficult.\n2.  **Black Box Nature:** It's hard to understand *why* an LLM produced a certain output, especially within complex chains involving multiple prompts, tools, retrievers, and other LLMs.\n3.  **Debugging Complexity:** Traditional debugging tools don't map well to LLM ch
# ...

# %%
## Stroutput Parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt|llm|output_parser

response = chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# As an AI Engineer, I can tell you that **LangSmith** is a powerful platform developed by the creators of LangChain, designed to help developers build, debug, evaluate, and monitor their Language Model (LLM) applications.
#
# In essence, it's an **observability and evaluation platform for LLM applications**.
#
# Here's a breakdown of what LangSmith is, why it's needed, and its core features:
#
# ---
#
# ### What is LangSmith?
#
# LangSmith is a **developer platform for LLM applications**. It provides a suite of tools and services to bring LLM-powered applications from prototype to production with confidence. It's particularly useful because LLM applications are inherently complex and non-deterministic, making traditional debugging and evaluation methods insufficient.
#
# ### Why is LangSmith Needed? (The Problem It Solves)
#
# Developing robust LLM applications presents unique challenges:
#
# ...
