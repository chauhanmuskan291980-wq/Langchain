# %%
# %pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.13.2-py3-none-any.whl (346 kB)
#      -------------------------------------- 346.6/346.6 KB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0 in e:\generativeai_python\venv\lib\site-packages (from pypdf) (4.15.0)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.13.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'e:\GenerativeAi_python\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader('Speech_1_Continuous_Learning.pdf')
docs = loader.load()

docs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-14T11:31:31+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-06-14T11:31:31+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'Speech_1_Continuous_Learning.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Speech 1: The Power of Continuous Learning\nThe Power of Continuous Learning Good morning everyone. Today I would like to speak about the\npower of continuous learning. In a world that changes every day, learning is no longer limited to\nschools and colleges. It has become a lifelong journey that helps us grow personally and\nprofessionally. Technology is evolving rapidly. New tools, new careers, and new opportunities are\ncreated every year. The skills that were valuable a few years ago may not be enough today. This is\nwhy continuous learning is important. It allows us to stay updated, improve our abilities, and remain\nconfident in a competitive environment. Learning does not always mean earning another degree. It\ncan be as simple as reading books, taking online courses, attending workshops, listening to\npodcasts, or learning from experienced people around us. Every small effort adds to our knowledge\nand helps us become better versions of ourselves. One of the greatest benefits of continuous\nlearning is adaptability. People who are willing to learn can adjust to change more easily. Instead of\nfearing new challenges, they see them as opportunities to grow. This mindset is especially\nimportant for students and professionals who want to succeed in a fast-changing world. Continuous\nlearning also improves creativity and problem-solving skills. When we expose ourselves to new\nideas, we develop different ways of thinking. We become more capable of finding solutions, making\nbetter decisions, and contributing positively to our organizations and communities. Another\nadvantage is personal confidence. Knowledge gives us the courage to take on responsibilities and\npursue ambitious goals. Every new skill we acquire strengthens our belief in our abilities. This\nconfidence often leads to better performance and greater success. However, learning requires\nconsistency and discipline. It is easy to postpone learning when we are busy. The key is to dedicate\na small amount of time every day. Even thirty minutes of focused learning can create significant\nresults over time. Small efforts, when repeated consistently, lead to remarkable growth. In\nconclusion, continuous learning is one of the most valuable investments we can make in ourselves.\nIt helps us adapt to change, improve our skills, increase confidence, and create new opportunities.\nNo matter our age or profession, there is always something new to learn. Let us embrace the habit\nof learning every day and continue growing throughout our lives. Thank you.')]

# %%
## How to recursively split text by characters
# %pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in e:\generativeai_python\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in e:\generativeai_python\venv\lib\site-packages (from langchain-text-splitters) (1.4.7)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.15)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: langchain-protocol>=0.0.14 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.17)
# Requirement already satisfied: packaging>=23.2.0 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\generativeai_python\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in e:\generativeai_python\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: websockets>=15.0 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: orjson>=3.9.14 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests>=2.0.0 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\generativeai_python\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\generativeai_python\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\generativeai_python\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: pydantic-core==2.46.4 in e:\generativeai_python\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: httpcore==1.* in e:\generativeai_python\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: certifi in e:\generativeai_python\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.5.20)
# Requirement already satisfied: anyio in e:\generativeai_python\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.13.0)
# Requirement already satisfied: idna in e:\generativeai_python\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in e:\generativeai_python\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\generativeai_python\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\generativeai_python\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in e:\generativeai_python\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'e:\GenerativeAi_python\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

final_documents = text_splitter.split_documents(docs)

print(len(final_documents))
print(final_documents[0].page_content)
# Out:
# 6
# Speech 1: The Power of Continuous Learning
# The Power of Continuous Learning Good morning everyone. Today I would like to speak about the
# power of continuous learning. In a world that changes every day, learning is no longer limited to
# schools and colleges. It has become a lifelong journey that helps us grow personally and
# professionally. Technology is evolving rapidly. New tools, new careers, and new opportunities are

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('Speech_3_Technology.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'Speech_3_Technology.txt'}, page_content='The Role of Technology in Modern Society\n\nGood evening everyone. Today I would like to talk about the role of technology in modern society. Technology has become an integral part of our daily lives and continues to influence the way we learn, work, communicate, and solve problems.\n\nFrom smartphones and computers to artificial intelligence and cloud computing, technology has transformed nearly every industry. It has made communication faster, information more accessible, and services more efficient. People can connect with others across the world within seconds and access educational resources from almost anywhere.\n\nIn the field of education, technology has created new opportunities for learning. Online courses, digital libraries, and virtual classrooms have made education more flexible and accessible. Students can learn at their own pace and gain knowledge from experts around the globe.\n\nTechnology has also improved healthcare. Advanced medical equipment, digital records, and telemedicine services help doctors diagnose and treat patients more effectively. These innovations save time, reduce errors, and improve patient outcomes.\n\nBusinesses have benefited greatly from technological advancements as well. Automation, data analytics, and digital communication tools help organizations increase productivity and make informed decisions. Small businesses can now reach customers worldwide through online platforms.\n\nDespite its advantages, technology also presents challenges. Excessive screen time, cybersecurity threats, and concerns about privacy are important issues that require attention. Society must use technology responsibly and develop ethical practices to ensure that innovation benefits everyone.\n\nAnother important aspect is the impact of technology on employment. While automation may replace certain tasks, it also creates new job opportunities that require advanced skills. This highlights the importance of continuous learning and adapting to changing workplace demands.\n\nTechnology can also be a powerful tool for solving global challenges. Innovations in renewable energy, agriculture, transportation, and environmental monitoring contribute to sustainable development and improve quality of life for future generations.\n\nIn conclusion, technology plays a vital role in shaping modern society. It offers countless opportunities for growth, innovation, and progress. However, its benefits can only be fully realized when it is used responsibly and ethically. By embracing technology while addressing its challenges, we can create a better and more connected world. Thank you.')]

# %%
speech=""
with open('Speech_3_Technology.txt') as f:
    speech = f.read()

speech

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text = text_splitter.create_documents([speech])
text[0].page_content
# Out:
# 'The Role of Technology in Modern Society'
