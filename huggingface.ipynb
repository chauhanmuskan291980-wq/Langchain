# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %%
# %pip install sentence-transformers
# Out:
# ...
#      -------------------------------------- 596.4/596.4 KB 3.8 MB/s eta 0:00:00
# ...
#      -------------------------------------- 122.9/122.9 MB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 11.2/11.2 MB 2.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 309.1/309.1 KB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 134.9/134.9 KB 4.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.7/2.7 MB 2.9 MB/s eta 0:00:00
# ...
#      ------------------------------------ 355.5/355.5 KB 480.9 kB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.23.1
#     Uninstalling tokenizers-0.23.1:
#       Successfully uninstalled tokenizers-0.23.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 26.1.2 is available.
# ...

# %%
# %pip install -U langchain-huggingface
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting langchain-huggingface
# ...
# WARNING: You are using pip version 22.0.4; however, version 26.1.2 is available.
# You should consider upgrading via the 'e:\GenerativeAi_python\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Sentences Transformers on Hugging Face
# Hugging face sentences-transformers is a python framework for state-of-the-art sentence , text and image embeddings. One of the embedding models is used in the Hugging Face Embeddings class. We have also added an alias for sentencesTransformerEmbeddings for users who are more familiar with dirctly using the package.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

text="Hello world"
vector = embeddings.embed_query(text)

print(len(vector))
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 4642.06it/s]
# 384

# %%
doc_result = embeddings.embed_documents([text,"This is not a test document."])
doc_result
# Out:
# [[-0.03447726368904114,
#   0.031023221090435982,
#   0.006734971422702074,
#   0.02610897272825241,
#   -0.0393620990216732,
#   -0.16030247509479523,
#   0.0669240653514862,
#   -0.006441404111683369,
#   -0.047450531274080276,
#   0.014758880250155926,
#   0.0708753913640976,
#   0.05552760139107704,
#   0.01919335499405861,
#   -0.02625136263668537,
#   -0.010109594091773033,
#   -0.026940489187836647,
#   0.022307435050606728,
#   -0.022226674482226372,
#   -0.1496926248073578,
#   -0.017493102699518204,
#   0.007676190696656704,
#   0.054352276027202606,
#   0.003254480194300413,
#   0.031725965440273285,
#   -0.08462142944335938,
#   -0.02940591797232628,
#   0.051595624536275864,
#   0.048124030232429504,
#   -0.003314772853627801,
#   -0.05827920511364937,
#   0.04196930304169655,
#   0.02221069298684597,
#   0.12818892300128937,
#   -0.022338896989822388,
#   -0.011656321585178375,
#   0.06292835623025894,
#   -0.0328763872385025,
#   -0.09122610837221146,
# ...
